# %%
import pandas as pd
from contacts.models import ContactBuyer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-1145b4141200> in <module>
#       1 import pandas as pd
# ----> 2 from contacts.models import ContactBuyer
#
# ModuleNotFoundError: No module named 'contacts'

# %%
df_sales = pd.read_excel("Sales_Order.xls",sheet_name="Sales Order")

# %%
df_sales.head(10)
# Out:
#    Order Date Shipment Date SalesOrder Number Status  \
# 0  2018-04-27    2018-05-18          SO-00004   open
# 1  2018-04-27    2018-05-18          SO-00004   open
# 2  2018-04-27    2018-05-18          SO-00004   open
# 3  2018-04-27    2018-05-18          SO-00004   open
# 4  2018-04-27    2018-05-18          SO-00004   open
# 5  2018-04-27    2018-05-18          SO-00004   open
# 6  2018-04-27    2018-05-18          SO-00004   open
# 7  2018-04-27    2018-05-18          SO-00004   open
# 8  2018-05-12    2018-05-18          SO-00004   open
# 9  2018-05-12    2018-05-18          SO-00004   open
#
#                       Customer Name Place of Supply  \
# 0  BHASKAR HERBACEUTICALS PVT. LTD.             NaN
# 1  BHASKAR HERBACEUTICALS PVT. LTD.             NaN
# 2  BHASKAR HERBACEUTICALS PVT. LTD.             NaN
# 3  BHASKAR HERBACEUTICALS PVT. LTD.             NaN
# 4  BHASKAR HERBACEUTICALS PVT. LTD.             NaN
# 5  BHASKAR HERBACEUTICALS PVT. LTD.             NaN
# ...
