# %%
from deals.models import ZohoSalesOrder
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-1-84dea1fe7d2a> in <module>
# ----> 1 from deals.models import ZohoSalesOrder
#
# ~/rawbleadmin/deals/models.py in <module>
#       1 from django.db import models
# ----> 2 from contacts.models import ContactBuyer,ContactVendor
#       3 from django.contrib.auth.models import User
#       4 from products.models import ProductGroup,Product,Make,Unit
#       5 import datetime
#
# ~/rawbleadmin/contacts/models.py in <module>
#       1 from django.db import models
# ----> 2 from products.models import Product
#       3
#       4
#       5
#
# ~/rawbleadmin/products/models.py in <module>
#       1 from django.db import models
# ----> 2 from gdstorage.storage import GoogleDriveStorage
#       3 from django.contrib.auth.models import User
#       4 # Define Google Drive Storage
#       5 gd_storage = GoogleDriveStorage()
# ...
